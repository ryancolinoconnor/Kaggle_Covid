# %%
import sys
from utils import pipeline
sys.path.append('./utils/')



pl = pipeline.Pipeline()
pl.__BASE_PATH__ = './CORD-19-research-challenge/'

# %%
list(filter(lambda x:x,
    list(map(lambda x:(x[0].replace(os.path.sep,'/')) in x[0],os.walk(pl.__BASE_PATH__)))))
# Out:
# ['./CORD-19-research-challenge/biorxiv_medrxiv/biorxiv_medrxiv',
#  './CORD-19-research-challenge/comm_use_subset/comm_use_subset',
#  './CORD-19-research-challenge/custom_license/custom_license',
#  './CORD-19-research-challenge/noncomm_use_subset/noncomm_use_subset']

# %%
import os

# %%
#pl = pipeline.Pipeline()
print(pl.get_folders())
data = pl.get_files_for_folder(pl.get_folders()[-1],limit=5)
data
# Out:
# ['./CORD-19-research-challenge/biorxiv_medrxiv/biorxiv_medrxiv', './CORD-19-research-challenge/comm_use_subset/comm_use_subset', './CORD-19-research-challenge/custom_license/custom_license', './CORD-19-research-challenge/noncomm_use_subset/noncomm_use_subset']
#                                             abstract  \
# 0  [{'text': 'and Blautia (P = 0.008) significant...
# 0  [{'text': 'Accurate and rapid diagnosis of hig...
# 0  [{'text': 'A high percentage (up to 90%) of dr...
# 0  [{'text': '253 protein, C-reactive protein (CR...
# 0                                                 []
#
#                                          back_matter  \
# 0                                                 []
# 0  [{'text': 'The authors have declared that no c...
# 0  [{'text': 'We would like to acknowledge the su...
# 0                                                 []
# 0                                                 []
#
# ...
